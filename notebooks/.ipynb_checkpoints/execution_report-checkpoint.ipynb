# %%
from watermark import watermark
import os
import sys

PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
sys.path.append(os.path.join(PROJ_ROOT, 'src'))
sys.path.append("../")

# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas
# Out:
# Thu Oct 04 2018
#
# CPython 3.5.6
# IPython 6.5.0
#
# numpy 1.15.2
# scipy 1.1.0
# sklearn 0.20.0
# pandas 0.23.4
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.15.0-34-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, Image

from src.data import preprocess
from src.visualization import exploratory
from src.models import train_models
from src.evaluation import model_performance
from src.commons import constants

print(constants.PROJ_ROOT)
# Out:
# /home/utsav/PycharmProjects/kaggle-bio-response/src/commons/../..

# %%
dframe = preprocess.read_raw_data()
dframe.head()
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...    D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...        0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...        1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...        0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...        0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...        0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# ...

# %%
dframe = preprocess.preprocess_data(dframe)
dframe.describe()
# Out:
#           Activity            D1            D2            D3            D5  \
# count  3751.000000  3.751000e+03  3.751000e+03  3.751000e+03  3.751000e+03
# mean      0.542255 -2.083703e-17 -2.225774e-17  1.231279e-17  9.471377e-19
# std       0.498278  1.000133e+00  1.000133e+00  1.000133e+00  1.000133e+00
# min       0.000000 -9.621116e-01 -2.931697e+00 -8.691145e-01 -2.042169e+00
# 25%       0.000000 -5.457480e-01 -7.050384e-01 -8.691145e-01 -7.213447e-01
# 50%       1.000000 -1.281340e-01 -6.090881e-02 -2.313898e-01 -2.065351e-01
# 75%       1.000000  2.882296e-01  7.176351e-01  4.063348e-01  4.836692e-01
# max       1.000000  1.154130e+01  3.514009e+00  1.124765e+01  7.680862e+00
#
#                  D6            D7            D8            D9           D10  \
# count  3.751000e+03  3.751000e+03  3.751000e+03  3.751000e+03  3.751000e+03
# mean   1.183922e-17 -3.030841e-17 -9.471377e-18  6.629964e-18  1.823240e-17
# ...

# %%
dframe.head()
# Out:
#    Activity        D1        D2        D3        D5        D6        D7  \
# 0         1 -0.962112 -0.901566  0.406335 -0.771664 -0.109575 -0.017182
# 1         1  3.622473  0.130899 -0.231390 -0.983668  1.484291 -1.873312
# 2         1 -0.545748 -1.061088 -0.869114 -0.022620 -0.969645  0.908173
# 3         1 -0.962112 -0.506505 -0.869114 -0.153712  0.477511 -0.434494
# 4         0  0.288230 -0.705193 -0.869114  2.755187  1.204300 -1.337163
#
#          D8        D9       D10    ...        D1699     D1709     D1718  \
# 0  0.800886 -0.081646 -0.283699    ...    -0.164646 -0.128574 -0.126414
# 1 -0.266603  1.214430 -1.705571    ...     6.073622 -0.128574  7.910516
# 2  0.384653 -0.982879  0.852064    ...    -0.164646 -0.128574 -0.126414
# 3 -1.022490  0.775435 -0.639053    ...    -0.164646 -0.128574 -0.126414
# 4 -0.930022  0.880558 -1.511041    ...    -0.164646 -0.128574 -0.126414
#
#       D1728     D1729     D1731     D1739     D1746     D1763     D1768
# ...

# %%
dframe.corr()['Activity']
# Out:
# Activity    1.000000
# D1         -0.086402
# D2          0.109226
# D3          0.167209
# D5         -0.148447
# D6         -0.106213
# D7          0.137016
# D8          0.172226
# D9         -0.077743
# D10         0.179096
# D11        -0.113418
# D13        -0.078850
# D14         0.062848
# D15        -0.051852
# D16         0.106524
# D17         0.050995
# D18         0.123787
# D19        -0.085130
# D20        -0.141740
# D21        -0.081993
# D23         0.051452
# D26        -0.129470
# D27         0.472340
# D30        -0.073914
# D31        -0.125265
# D32         0.066498
# D35        -0.091223
# D36        -0.055675
# D41        -0.087285
# D43         0.118729
#               ...
# D1545       0.053382
# D1552       0.054871
# D1569       0.055525
# D1571       0.074129
# D1580       0.055877
# D1582       0.052297
# D1585       0.057536
# D1589       0.068839
# D1596       0.070812
# D1598       0.064167
# D1613       0.058657
# D1637       0.050440
# ...

# %%
fig = exploratory.target_correlation_plot(dframe)

# %%
train_models.train_save_benchmark_model()
train_models.train_save_improved_models()
# Out:
# /home/utsav/.conda/envs/kaggle/lib/python3.5/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
model_performance.show_benchmark_model_performance()
# Out:
# Calculating benchmark model performance:
# _____________________________________________________________________________________
#
# Performance of SVM
# -------------------------------------------------------------------------------------
#
# confusion_matrix:
# [[251  93]
#  [ 99 308]]
#
# classification_report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.72       344
#            1       0.77      0.76      0.76       407
#
#    micro avg       0.74      0.74      0.74       751
#    macro avg       0.74      0.74      0.74       751
# weighted avg       0.74      0.74      0.74       751
#
#
# accuracy_score:	0.744
#
# roc_auc_score:	0.743
#
# log_loss:	8.830
# _____________________________________________________________________________________

# %%
display(Image(constants.BENCHMARK_ROC_PATH))

# %%
model_performance.show_improved_model_performances(dframe)
# Out:
# Calculating improved models performances:
# _____________________________________________________________________________________
#
# Performance of RandomForest
# -------------------------------------------------------------------------------------
#
# confusion_matrix:
# [[281  63]
#  [ 69 338]]
#
# classification_report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       344
#            1       0.84      0.83      0.84       407
#
#    micro avg       0.82      0.82      0.82       751
#    macro avg       0.82      0.82      0.82       751
# weighted avg       0.82      0.82      0.82       751
#
#
# accuracy_score:	0.824
#
# roc_auc_score:	0.824
#
# log_loss:	6.071
# _____________________________________________________________________________________
# _____________________________________________________________________________________
#
# Performance of LogisticRegression
# ...

# %%
display(Image(constants.ROC_CURVES_PATH))
